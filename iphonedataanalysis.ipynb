# %% [markdown]
# <a href="https://colab.research.google.com/github/amannayanmujawar/my-firt-project-idata-visualization-of-bitcoin-sentiment-data/blob/main/iphonedataanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/iphone.csv")

# %%
df.shape
# Out:
# (100, 10)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Name', 'Country', 'iPhone_Model', 'Storage',
#        'Color', 'Quantity', 'Price', 'Sale_Date', 'Payment_Method'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1001, 'Customer_1', 'USA', 'iPhone 13', '256GB', 'Purple', 5,
#         1817, '01-05-2025', 'Debit Card'],
#        [1002, 'Customer_2', 'Canada', 'iPhone 12', '256GB', 'Blue', 1,
#         998, '05-03-2025', 'PayPal'],
#        [1003, 'Customer_3', 'Canada', 'iPhone 15 Pro Max', '512GB',
#         'Black', 5, 876, '25-01-2025', 'Credit Card'],
#        [1004, 'Customer_4', 'USA', 'iPhone 15 Pro Max', '512GB', 'Black',
#         2, 1290, '24-03-2025', 'Debit Card'],
#        [1005, 'Customer_5', 'USA', 'iPhone 15', '128GB', 'Blue', 3, 1092,
#         '01-02-2025', 'Debit Card'],
#        [1006, 'Customer_6', 'UAE', 'iPhone 14 Pro', '256GB', 'Red', 5,
#         1939, '15-02-2025', 'Debit Card'],
#        [1007, 'Customer_7', 'Germany', 'iPhone 14 Pro', '512GB', 'Blue',
#         1, 1798, '13-02-2025', 'Debit Card'],
#        [1008, 'Customer_8', 'UK', 'iPhone 15 Pro Max', '128GB', 'Purple',
#         3, 1808, '30-03-2025', 'Debit Card'],
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        100 non-null    int64
#  1   Customer_Name   100 non-null    object
#  2   Country         100 non-null    object
#  3   iPhone_Model    100 non-null    object
#  4   Storage         100 non-null    object
#  5   Color           100 non-null    object
#  6   Quantity        100 non-null    int64
#  7   Price           100 non-null    int64
#  8   Sale_Date       100 non-null    object
#  9   Payment_Method  100 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Customer_Name     0
# Country           0
# iPhone_Model      0
# Storage           0
# Color             0
# Quantity          0
# Price             0
# Sale_Date         0
# Payment_Method    0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Order_ID          100
# Customer_Name     100
# Country           100
# iPhone_Model      100
# Storage           100
# Color             100
# Quantity          100
# Price             100
# Sale_Date         100
# Payment_Method    100
# dtype: int64

# %%
df.describe()
# Out:
#           Order_ID    Quantity        Price
# count   100.000000  100.000000   100.000000
# mean   1050.500000    3.330000  1468.750000
# std      29.011492    1.484295   388.367637
# min    1001.000000    1.000000   718.000000
# 25%    1025.750000    2.000000  1123.750000
# 50%    1050.500000    3.000000  1571.500000
# 75%    1075.250000    5.000000  1794.250000
# max    1100.000000    5.000000  1992.000000

# %%
df.count()
# Out:
# Order_ID          100
# Customer_Name     100
# Country           100
# iPhone_Model      100
# Storage           100
# Color             100
# Quantity          100
# Price             100
# Sale_Date         100
# Payment_Method    100
# dtype: int64

# %%
df.head()
# Out:
#    Order_ID Customer_Name Country       iPhone_Model Storage   Color  \
# 0      1001    Customer_1     USA          iPhone 13   256GB  Purple
# 1      1002    Customer_2  Canada          iPhone 12   256GB    Blue
# 2      1003    Customer_3  Canada  iPhone 15 Pro Max   512GB   Black
# 3      1004    Customer_4     USA  iPhone 15 Pro Max   512GB   Black
# 4      1005    Customer_5     USA          iPhone 15   128GB    Blue
#
#    Quantity  Price   Sale_Date Payment_Method
# 0         5   1817  01-05-2025     Debit Card
# 1         1    998  05-03-2025         PayPal
# 2         5    876  25-01-2025    Credit Card
# 3         2   1290  24-03-2025     Debit Card
# 4         3   1092  01-02-2025     Debit Card

# %%
df.tail()
# Out:
#     Order_ID Customer_Name  Country       iPhone_Model Storage   Color  \
# 95      1096   Customer_96      UAE      iPhone 14 Pro   256GB    Blue
# 96      1097   Customer_97       UK  iPhone 15 Pro Max   512GB   White
# 97      1098   Customer_98       UK  iPhone 15 Pro Max   512GB   White
# 98      1099   Customer_99  Germany  iPhone 15 Pro Max   512GB  Purple
# 99      1100  Customer_100       UK          iPhone 15   512GB    Blue
#
#     Quantity  Price   Sale_Date Payment_Method
# 95         1   1743  09-03-2025    Credit Card
# 96         3   1671  08-02-2025    Credit Card
# 97         4   1125  08-01-2025     Debit Card
# 98         5   1540  04-02-2025     Debit Card
# 99         3   1549  28-03-2025     Debit Card

# %% [markdown]
# **Accessing the data from dataframe**

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_Name', 'Country', 'iPhone_Model', 'Storage',
#        'Color', 'Quantity', 'Price', 'Sale_Date', 'Payment_Method'],
#       dtype='object')

# %%
df[]
